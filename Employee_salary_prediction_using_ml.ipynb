# %%
#Employee Salary prediction model using linear regression
#Import pandas Library
import pandas as pd

# %%
#importing dataset and storing under the variable "df"
df=pd.read_csv("/content/Salary Data.csv")

# %%
df
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
#print the number of rows and coloumns in the dataset
df.shape
# Out:
# (375, 6)

# %%
#check for duplicates
duplicates = df.duplicated().sum()

# %%
#remove duplicates
df.drop_duplicates(inplace=True)

# %%
#row 172,260
print(df.isna())
# Out:
#        Age  Gender  Education Level  Job Title  Years of Experience  Salary
# 0    False   False            False      False                False   False
# 1    False   False            False      False                False   False
# 2    False   False            False      False                False   False
# 3    False   False            False      False                False   False
# 4    False   False            False      False                False   False
# ..     ...     ...              ...        ...                  ...     ...
# 348  False   False            False      False                False   False
# 349  False   False            False      False                False   False
# 350  False   False            False      False                False   False
# 351  False   False            False      False                False   False
# 371  False   False            False      False                False   False
#
# [325 rows x 6 columns]

# %%
#check for null values
df.isnull().sum()
# Out:
# Age                    1
# Gender                 1
# Education Level        1
# Job Title              1
# Years of Experience    1
# Salary                 1
# dtype: int64

# %%
#remove rows with null values
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (324, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 324 entries, 0 to 371
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  324 non-null    float64
#  1   Gender               324 non-null    object
#  2   Education Level      324 non-null    object
#  3   Job Title            324 non-null    object
#  4   Years of Experience  324 non-null    float64
#  5   Salary               324 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 17.7+ KB

# %%
df.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
#check no of values
df.Age.value_counts()
# Out:
# Age
# 29.0    20
# 33.0    19
# 36.0    18
# 31.0    18
# 44.0    15
# 45.0    14
# 35.0    14
# 34.0    14
# 30.0    14
# 47.0    13
# 39.0    12
# 40.0    12
# 38.0    12
# 37.0    12
# 32.0    12
# 42.0    11
# 28.0    11
# 43.0    11
# 41.0    10
# 46.0     9
# 27.0     9
# 48.0     8
# 26.0     7
# 49.0     7
# 50.0     7
# 51.0     5
# 25.0     4
# 52.0     3
# 24.0     1
# 23.0     1
# 53.0     1
# Name: count, dtype: int64

# %%
df.Gender.value_counts()
# Out:
# Gender
# Male      170
# Female    154
# Name: count, dtype: int64

# %%
df['Education Level'].value_counts()
# Out:
# Education Level
# Bachelor's    191
# Master's       91
# PhD            42
# Name: count, dtype: int64

# %%
df['Job Title'].value_counts()
# Out:
# Job Title
# Director of Operations            9
# Director of Marketing             8
# Senior Marketing Manager          8
# Senior Project Manager            7
# Senior Data Scientist             6
#                                  ..
# Junior Social Media Specialist    1
# Junior Operations Coordinator     1
# Senior HR Specialist              1
# Director of HR                    1
# Junior Financial Advisor          1
# Name: count, Length: 174, dtype: int64

# %%
df['Years of Experience'].value_counts()
# Out:
# Years of Experience
# 3.0     27
# 2.0     26
# 9.0     19
# 8.0     17
# 10.0    16
# 4.0     16
# 7.0     16
# 5.0     16
# 16.0    15
# 12.0    14
# 19.0    13
# 20.0    13
# 15.0    12
# 21.0    11
# 18.0    11
# 6.0     11
# 14.0    11
# 1.5     11
# 13.0    10
# 11.0     9
# 22.0     8
# 1.0      7
# 17.0     5
# 0.0      3
# 25.0     3
# 23.0     2
# 24.0     1
# 0.5      1
# Name: count, dtype: int64

# %%
df=df[df['Years of Experience'] != 0.5]
df=df[df['Years of Experience'] != 0.0]

# %%
df['Years of Experience'].value_counts()
# Out:
# Years of Experience
# 3.0     27
# 2.0     26
# 9.0     19
# 8.0     17
# 5.0     16
# 7.0     16
# 10.0    16
# 4.0     16
# 16.0    15
# 12.0    14
# 20.0    13
# 19.0    13
# 15.0    12
# 1.5     11
# 14.0    11
# 6.0     11
# 21.0    11
# 18.0    11
# 13.0    10
# 11.0     9
# 22.0     8
# 1.0      7
# 17.0     5
# 25.0     3
# 23.0     2
# 24.0     1
# Name: count, dtype: int64

# %%
df['Salary'].value_counts()
# Out:
# Salary
# 40000.0     26
# 120000.0    20
# 50000.0     19
# 95000.0     18
# 45000.0     18
# 180000.0    17
# 90000.0     15
# 160000.0    14
# 140000.0    14
# 110000.0    14
# 170000.0    13
# 60000.0     13
# 150000.0    12
# 100000.0    12
# 80000.0     12
# 130000.0    11
# 55000.0     10
# 65000.0      9
# 35000.0      9
# 70000.0      8
# 105000.0     6
# 85000.0      5
# 75000.0      4
# 190000.0     4
# 115000.0     3
# 250000.0     2
# 200000.0     2
# 175000.0     2
# 135000.0     2
# 125000.0     1
# 220000.0     1
# 185000.0     1
# 145000.0     1
# 155000.0     1
# 350.0        1
# Name: count, dtype: int64

# %%
df=df[df['Salary'] != 350.0]
Q1 = df['Salary'].quantile(0.25)
Q3 = df['Salary'].quantile(0.75)
IQR = Q3 - Q1
df = df[(df['Salary'] >= Q1 - 1.5 * IQR) & (df['Salary'] <= Q3 + 1.5 * IQR)]


df = df[df['Salary'] > 0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 319 entries, 0 to 371
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  319 non-null    float64
#  1   Gender               319 non-null    object
#  2   Education Level      319 non-null    object
#  3   Job Title            319 non-null    object
#  4   Years of Experience  319 non-null    float64
#  5   Salary               319 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 17.4+ KB

# %%
#outlier
import matplotlib.pyplot as plt
plt.boxplot(df['Age'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
plt.boxplot(df['Years of Experience'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['Gender'] = df['Gender'].str.lower().str.strip()
df['Education Level'] = df['Education Level'].str.lower().str.strip()
df['Job Title'] = df['Job Title'].str.lower().str.strip()

# %%
#labelencoding converting character into numbers
from sklearn.preprocessing import LabelEncoder
encoder_one=LabelEncoder()
encoder_two=LabelEncoder()
encoder_three=LabelEncoder()
df['Gender']=encoder_one.fit_transform(df['Gender'])
df['Education Level']=encoder_two.fit_transform(df['Education Level'])
df['Job Title']=encoder_three.fit_transform(df['Job Title'])
with open('gender_encoder.pkl', 'wb') as f:
    pickle.dump(encoder_one, f)
with open('education_encoder.pkl', 'wb') as f:
    pickle.dump(encoder_two, f)
with open('job_encoder.pkl', 'wb') as f:
    pickle.dump(encoder_three, f)
df
# Out:
#       Age  Gender  Education Level  Job Title  Years of Experience    Salary
# 0    32.0       1                0        156                  5.0   90000.0
# 1    28.0       0                1         17                  3.0   65000.0
# 2    45.0       1                2        127                 15.0  150000.0
# 3    36.0       0                0         99                  7.0   60000.0
# 4    52.0       1                1         21                 20.0  200000.0
# ..    ...     ...              ...        ...                  ...       ...
# 348  28.0       0                0         66                  1.0   35000.0
# 349  36.0       1                0        108                  8.0  110000.0
# 350  44.0       0                2        112                 16.0  160000.0
# 351  31.0       1                0         61                  3.0   55000.0
# 371  43.0       1                1         29                 19.0  170000.0
#
# [319 rows x 6 columns]

# %%
#divide dataset into input and output
x=df.drop(columns=['Salary']) #input-traininig
y=df['Salary'] #output-testing
x
# Out:
#       Age  Gender  Education Level  Job Title  Years of Experience
# 0    32.0       1                0        156                  5.0
# 1    28.0       0                1         17                  3.0
# 2    45.0       1                2        127                 15.0
# 3    36.0       0                0         99                  7.0
# 4    52.0       1                1         21                 20.0
# ..    ...     ...              ...        ...                  ...
# 348  28.0       0                0         66                  1.0
# 349  36.0       1                0        108                  8.0
# 350  44.0       0                2        112                 16.0
# 351  31.0       1                0         61                  3.0
# 371  43.0       1                1         29                 19.0
#
# [319 rows x 5 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
y
# Out:
# 0       90000.0
# 1       65000.0
# 2      150000.0
# 3       60000.0
# 4      200000.0
#          ...
# 348     35000.0
# 349    110000.0
# 350    160000.0
# 351     55000.0
# 371    170000.0
# Name: Salary, Length: 319, dtype: float64

# %%
# training testing spilt training spillter random state
# stratify is equallydistributed
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=23)

# %%
x_train
# Out:
#       Age  Gender  Education Level  Job Title  Years of Experience
# 65   38.0       0                1         20                 10.0
# 228  37.0       1                1        148                  9.0
# 144  25.0       0                1         63                  1.5
# 127  45.0       1                0        103                 18.0
# 20   34.0       0                1          3                  5.0
# ..    ...     ...              ...        ...                  ...
# 243  46.0       1                2        110                 19.0
# 32   29.0       1                1         18                  3.0
# 41   48.0       1                1         86                 18.0
# 236  37.0       0                0        115                  9.0
# 86   27.0       1                0         44                  2.0
#
# [255 rows x 5 columns]

# %%
#Implementing LinearRegression Algorithm
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(x_test)
predictions
# Out:
# array([162383.70395556, 161838.24834667, 128785.09338847, 171912.31593357,
#        167104.96725761,  39577.98692004,  42571.21201385,  58625.82142177,
#        152068.84148432,  84242.09893638,  89601.72769494,  49750.01724229,
#         42541.09500957, 109667.90812965,  44767.87490724, 154565.6110177 ,
#        139787.42245546,  37971.33898184, 180514.64324386,  89837.03151661,
#        199005.92932651,  52649.41023557, 163076.66775979,  43683.25504325,
#         43141.14896619,  46827.06515847, 130934.76965664, 128771.70830346,
#         98373.66077247,  89856.1838183 ,  52672.96932611, 110518.14642489,
#        101420.5619611 , 158476.00747897, 151090.51385539,  66484.20536944,
#        101578.62714916, 144809.45153869,  35932.22673347,  65689.92929803,
#         96338.81686059,  86913.15373162, 151100.55285682, 101297.80781498,
#         51041.97504857, 117267.56416922,  48222.8940667 ,  85165.95977344,
# ...

# %%
y_test
# Out:
# 136    140000.0
# 2      150000.0
# 231    120000.0
# 19     180000.0
# 197    155000.0
#          ...
# 29      90000.0
# 131     45000.0
# 128     50000.0
# 337     90000.0
# 119    120000.0
# Name: Salary, Length: 64, dtype: float64

# %%
#Root Mean Squared Error
from sklearn.metrics import mean_squared_error

import numpy as np

mse = mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Root Mean Squared Error (RMSE): 14319.532297358228

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, predictions, color='blue', edgecolor='k', alpha=0.7)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--', linewidth=2)
plt.title('Actual vs Predicted Values')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(predictions,y_test)
mse
# Out:
# 205049005.2150854

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(predictions,y_test)
mae
# Out:
# 10448.22987430953

# %%
from sklearn.metrics import r2_score
r2 =  r2_score(y_test,predictions)
r2
# Out:
# 0.9020727125500576

# %%
#Save model using pickle
import pickle
with open('salary_model.pkl', 'wb') as file:
    pickle.dump(model, file)
